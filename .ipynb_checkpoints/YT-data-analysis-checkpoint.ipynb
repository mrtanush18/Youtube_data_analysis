# %%
pip install --upgrade google-api-python-client

# %%
pip install pandas

# %%
pip install seaborn

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Get credentials and create an API client
api_key = 'AIzaSyA7eOKXzvPOeWGO1ZcgUu3iwTZ2fsBr48M'

channel_ids = ['UCT9zcQNlyht7fRlcjmflRSA', # Imagine dragons 
               'UCIwFjwMjI0y7PDBVEO9-bkQ', # Bieber
               'UC0C-w0YjGpqDXGB8IHb662A', # Ed Sheeran
               'UCqECaJ8Gagnn7YCbPEzWH6g' # Taylor Swift
              ]

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# # Fn to extract channel stats

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],       
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads']
                   )
        all_data.append(data)
        
    return all_data
#     return response

# %%
# get_channel_stats(youtube, channel_ids)
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_stats)
channel_data
# Out:
#      Channel_name Subscribers        Views Total_videos  \
# 0  ImagineDragons    31500000  18339099045          111
# 1      Ed Sheeran    54500000  32111406086          467
# 2    Taylor Swift    57300000  34038258988          227
# 3   Justin Bieber    72800000  31985109344          249
#
#                 playlist_id
# 0  UUT9zcQNlyht7fRlcjmflRSA
# 1  UU0C-w0YjGpqDXGB8IHb662A
# 2  UUqECaJ8Gagnn7YCbPEzWH6g
# 3  UUIwFjwMjI0y7PDBVEO9-bkQ

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
ax = sns.barplot(x='Channel_name', y='Subscribers', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Views', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Total_videos', data=channel_data)

# %% [markdown]
# # Function to get video ids

# %%
channel_data
# Out:
#      Channel_name  Subscribers        Views  Total_videos  \
# 0  ImagineDragons     31500000  18339099045           111
# 1      Ed Sheeran     54500000  32111406086           467
# 2    Taylor Swift     57300000  34038258988           227
# 3   Justin Bieber     72800000  31985109344           249
#
#                 playlist_id
# 0  UUT9zcQNlyht7fRlcjmflRSA
# 1  UU0C-w0YjGpqDXGB8IHb662A
# 2  UUqECaJ8Gagnn7YCbPEzWH6g
# 3  UUIwFjwMjI0y7PDBVEO9-bkQ

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='Ed Sheeran', 'playlist_id'].iloc[0]

# %%
playlist_id
# Out:
# 'UU0C-w0YjGpqDXGB8IHb662A'

# %%
def get_video_ids(youtube, playlist_id):
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId=playlist_id,
                maxResults = 50
              )
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId=playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token    
                        )
            response = request.execute()
            
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
            
    return video_ids
#     return response

# %%
video_ids = get_video_ids(youtube,playlist_id)

# %%
video_ids
# Out:
# ['4B3eeqDYw6Y',
#  'UVcJ-jaJkGo',
#  'SJH28tYExFo',
#  'zAkuuYzm8Y0',
#  'hJylZMu45jE',
#  'utJU6QvBhwI',
#  'Mmqmi4uHhzs',
#  '9Fnou7uUbzg',
#  'oFVPdmTy63o',
#  'vDvGQBQ9hHQ',
#  'r--l4dRD354',
#  '4hjrEvw91lE',
#  '-rRZSPYo0lI',
#  'ukAZCbVuqxw',
#  'BR4buZkqmHM',
#  'n1gE2hxWRz4',
#  'prkf68CvHIs',
#  'oSxqkER3N6Y',
#  '2ePxQffQilc',
#  'X5Xa5vqLYGs',
#  'e39J7EgEtfg',
#  '1xr-fIaNTDs',
#  '2fZ1WQhwwxM',
#  '4h4S32hb9Qk',
#  'la86TzTaUww',
#  'WOz3GWOhGMc',
#  'WOLu_bWKa5o',
#  'lsRpmTwuGng',
#  'i2BtG1CTU6E',
#  'sTQJkkkWPZs',
#  'gQX7XhHSLnU',
#  'inoTm9GWtyg',
#  '9ZQa5ayM3zU',
#  'BVdct8MG3eQ',
#  'R-ahuAZsNNo',
#  'T0brO3x4h30',
#  'xU-sc9EumHk',
#  'eQCfEk21lIQ',
#  'lTGP9o7yNOc',
#  'ZqiF_UtH6fw',
#  'YAMI-bwcQ2g',
#  'uDaUlP2x2Jk',
#  '218WUXMDMOM',
#  'RM3QEtBcsLA',
#  '-S6w30V_lt8',
#  '2Ch63xHNNd8',
#  'lsJJ6MR-6cE',
#  'LnCXn-Vt_Q4',
#  'jlEOaFspXrw',
#  'M1Ap5bsGccs',
#  'pm-gqrr9WRw',
#  'f3dPTcwW4KA',
#  'VzqqkDh_RMg',
#  'JpG0YhFFNCQ',
#  'MZHrh81taaI',
# ...

# %% [markdown]
# # Function to get video details

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               Published_date = video['snippet']['publishedAt'],
                               Views = video['statistics']['viewCount'],
                               Likes = video['statistics']['likeCount'],
                               Comments = video['statistics']['commentCount']                               
                               )
            all_video_stats.append(video_stats)
    
        return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Comments'] = pd.to_numeric(video_data['Comments'])

# %%
video_data
# Out:
#                                                 Title Published_date  \
# 0                                      I’m an artisté     2024-04-11
# 1         Ed Sheeran meets Shubman Gill & Tanmay Bhat     2024-04-05
# 2           Downloaded Temple Run, might delete later     2024-04-03
# 3                             Me and Kev trend qweens     2024-03-22
# 4   Also learnt that there’s no such thing as too ...     2024-03-18
# 5   Got to bring out @diljitdosanjh tonight in Mum...     2024-03-17
# 6   This is the Shape of Us. Spreading love togeth...     2024-03-13
# 7   Visited a school in Mumbai and swapped perform...     2024-03-12
# 8   Using Jakarta as the choir for Give Me Love, y...     2024-03-07
# 9   Singing Perfect to a stadium full of people ne...     2024-02-23
# 10  Got invited by the people at @pokemon to voice...     2024-02-22
# 11              Some under the stage action for y’all     2024-02-12
# 12                 When your Magikarp finally evolves     2024-02-01
# ...

# %%
top10_videos = video_data.sort_values(by='Views', ascending=False).head(10)

# %%
top10_videos
# Out:
#                                                Title Published_date   Views  \
# 0  Ed Sheeran - Spring (Live From Emily's Living ...     2023-10-02  147141
#
#    Likes  Comments
# 0   2537        82

# %%
ax1 = sns.barplot(x='Views',y='Title',data=top10_videos)

# %%
video_data
# Out:
#                                                 Title Published_date  \
# 0                                      I’m an artisté     2024-04-11
# 1         Ed Sheeran meets Shubman Gill & Tanmay Bhat     2024-04-05
# 2           Downloaded Temple Run, might delete later     2024-04-03
# 3                             Me and Kev trend qweens     2024-03-22
# 4   Also learnt that there’s no such thing as too ...     2024-03-18
# 5   Got to bring out @diljitdosanjh tonight in Mum...     2024-03-17
# 6   This is the Shape of Us. Spreading love togeth...     2024-03-13
# 7   Visited a school in Mumbai and swapped perform...     2024-03-12
# 8   Using Jakarta as the choir for Give Me Love, y...     2024-03-07
# 9   Singing Perfect to a stadium full of people ne...     2024-02-23
# 10  Got invited by the people at @pokemon to voice...     2024-02-22
# 11              Some under the stage action for y’all     2024-02-12
# 12                 When your Magikarp finally evolves     2024-02-01
# ...

# %% [markdown]
# # Adding month column to analyze no. of videos posted monthly, months when highest & lowest no of videos posted

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %% [markdown]
# strftime() fn:
# https://www.geeksforgeeks.org/python-strftime-function/#:~:text=1%2C%202%2C%E2%80%A6.%2C%2030-,%25b,-Abbreviated%20month%20name

# %%
# Format with commas and display views in millions
pd.options.display.float_format = '{:,.2f}'.format
video_data['Views'] = video_data['Views'] / 1000000  # Convert population to millions
video_data.rename(columns = {'Views':'Views(in millions)'}, inplace = True)

# %%
video_data
# Out:
#                                                 Title Published_date  \
# 0                                      I’m an artisté     2024-04-11
# 1         Ed Sheeran meets Shubman Gill & Tanmay Bhat     2024-04-05
# 2           Downloaded Temple Run, might delete later     2024-04-03
# 3                             Me and Kev trend qweens     2024-03-22
# 4   Also learnt that there’s no such thing as too ...     2024-03-18
# 5   Got to bring out @diljitdosanjh tonight in Mum...     2024-03-17
# 6   This is the Shape of Us. Spreading love togeth...     2024-03-13
# 7   Visited a school in Mumbai and swapped perform...     2024-03-12
# 8   Using Jakarta as the choir for Give Me Love, y...     2024-03-07
# 9   Singing Perfect to a stadium full of people ne...     2024-02-23
# 10  Got invited by the people at @pokemon to voice...     2024-02-22
# 11              Some under the stage action for y’all     2024-02-12
# 12                 When your Magikarp finally evolves     2024-02-01
# ...

# %%
videos_per_month = video_data.groupby('Month', as_index=False).size()

# %%
videos_per_month
# Out:
#   Month  size
# 0   Apr     3
# 1   Dec     2
# 2   Feb     4
# 3   Jan     2
# 4   Mar     6
# 5   Nov    19
# 6   Oct    14

# %%
videos_per_month.rename(columns = {'size':'No. of videos'}, inplace = True) 
videos_per_month
# Out:
#   Month  No. of videos
# 0   Apr              3
# 1   Dec              2
# 2   Feb              4
# 3   Jan              2
# 4   Mar              6
# 5   Nov             19
# 6   Oct             14

# %%
avg_views_per_month = video_data.groupby('Month', as_index=False).agg({'Views(in millions)':['mean']})
avg_views_per_month
# Out:
#   Month Views(in millions)
#                       mean
# 0   Apr               0.51
# 1   Dec               0.45
# 2   Feb               0.50
# 3   Jan               2.38
# 4   Mar               2.37
# 5   Nov               0.37
# 6   Oct               0.94

# %%
avg_views_per_month.dtypes
# Out:
# Month                        object
# Views(in millions)  mean    float64
# dtype: object

# %%
videos_per_month.reset_index(drop = True, inplace = True)
avg_views_per_month.reset_index(drop = True, inplace = True)

# %%
avg_views_per_video_by_month = pd.merge(videos_per_month, avg_views_per_month, on='Month')
avg_views_per_video_by_month
# Out:
#   Month  No. of videos  (Views(in millions), mean)
# 0   Apr              3                        0.51
# 1   Dec              2                        0.45
# 2   Feb              4                        0.50
# 3   Jan              2                        2.38
# 4   Mar              6                        2.37
# 5   Nov             19                        0.37
# 6   Oct             14                        0.94

# %%
avg_views_per_video_by_month.rename(columns = {avg_views_per_video_by_month.columns[-1]:'Views(in million)'}, inplace = True) 
# df = df.rename(columns={df.columns[-1]: 'newname'})
avg_views_per_video_by_month
# Out:
#   Month  No. of videos  Views(in million)
# 0   Apr              3               0.51
# 1   Dec              2               0.45
# 2   Feb              4               0.50
# 3   Jan              2               2.38
# 4   Mar              6               2.37
# 5   Nov             19               0.37
# 6   Oct             14               0.94

# %%
avg_views_per_video_by_month.dtypes
# Out:
# Month                 object
# No. of videos          int64
# Views(in million)    float64
# dtype: object

# %%
ax2 = sns.barplot(x='Month', y='No. of videos', data=videos_per_month)

# %%
ax3 = sns.barplot(x='Month', y='Views(in million)', data=avg_views_per_video_by_month)

# %%
video_data
# Out:
#                                                 Title Published_date  \
# 0                                      I’m an artisté     2024-04-11
# 1         Ed Sheeran meets Shubman Gill & Tanmay Bhat     2024-04-05
# 2           Downloaded Temple Run, might delete later     2024-04-03
# 3                             Me and Kev trend qweens     2024-03-22
# 4   Also learnt that there’s no such thing as too ...     2024-03-18
# 5   Got to bring out @diljitdosanjh tonight in Mum...     2024-03-17
# 6   This is the Shape of Us. Spreading love togeth...     2024-03-13
# 7   Visited a school in Mumbai and swapped perform...     2024-03-12
# 8   Using Jakarta as the choir for Give Me Love, y...     2024-03-07
# 9   Singing Perfect to a stadium full of people ne...     2024-02-23
# 10  Got invited by the people at @pokemon to voice...     2024-02-22
# 11              Some under the stage action for y’all     2024-02-12
# 12                 When your Magikarp finally evolves     2024-02-01
# ...

# %%
video_data.to_csv('Video_details(Ed Sheeran).csv')
